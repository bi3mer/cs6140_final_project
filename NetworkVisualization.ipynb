# %%
from ann_visualizer.visualize import ann_viz
import pickle
import os

# %%
nn = pickle.load(open(os.path.join('mdl', 'nn5_all.pkl'), 'rb'))
# Out:
# Using TensorFlow backend.
# /usr/local/anaconda3/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:526: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /usr/local/anaconda3/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:527: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /usr/local/anaconda3/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:528: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# ...

# %%
nn.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense_5 (Dense)              (None, 128)               16512
# _________________________________________________________________
# dense_6 (Dense)              (None, 32)                4128
# _________________________________________________________________
# dense_7 (Dense)              (None, 16)                528
# _________________________________________________________________
# dense_8 (Dense)              (None, 8)                 136
# _________________________________________________________________
# dense_9 (Dense)              (None, 4)                 36
# _________________________________________________________________
# dense_10 (Dense)             (None, 1)                 5
# ...
# Total params: 21,345
# Trainable params: 21,345
# Non-trainable params: 0
# ...

# %%
from keras.utils.vis_utils import plot_model
plot_model(nn, show_shapes=True)

# %%
ann_viz(nn, title='Five Layer Network')

# %%
import pandas as pd
for c in pd.read_csv('data/train_x_all.csv'):
    print(c)
# Out:
# img_feature_0
# img_feature_1
# img_feature_2
# img_feature_3
# img_feature_4
# category_id_1.0
# category_id_2.0
# category_id_10.0
# category_id_15.0
# category_id_17.0
# category_id_19.0
# category_id_20.0
# category_id_22.0
# category_id_23.0
# category_id_24.0
# category_id_25.0
# category_id_26.0
# category_id_27.0
# category_id_28.0
# category_id_29.0
# category_id_43.0
# publish_day_Friday
# publish_day_Monday
# publish_day_Saturday
# publish_day_Sunday
# publish_day_Thursday
# publish_day_Tuesday
# publish_day_Wednesday
# word_encodings0
# word_encodings1
# word_encodings2
# word_encodings3
# word_encodings4
# word_encodings5
# word_encodings6
# word_encodings7
# word_encodings8
# word_encodings9
# word_encodings10
# word_encodings11
# word_encodings12
# word_encodings13
# word_encodings14
# word_encodings15
# word_encodings16
# word_encodings17
# word_encodings18
# word_encodings19
# word_encodings20
# word_encodings21
# word_encodings22
# word_encodings23
# ...
